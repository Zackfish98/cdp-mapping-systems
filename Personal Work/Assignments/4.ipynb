# %% [markdown]
# # HAR IP Map — shorelineeast.com
#
# ## Overview
# Captured browser requests from shorelineeast.com and geolocated the server IPs.
# 4 unique IPs found across the US — two in San Francisco (Cloudflare CDN),
# one in Branford CT (the actual server), one on the East Coast.
#
# ## Map — Full View
# ![Full map view](4 Inputs/ShorelineWholeMap.png)
#
# ## Map — San Francisco (Cloudflare CDN)
# ![San Francisco servers](4 Inputs/SanFranciscoMap.png)
#
# ## Map — New Haven CT (Origin Server)
# ![New Haven server](4 Inputs/NewHavenMap.png)
